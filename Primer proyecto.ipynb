# %%
import random

lambetazo = ["Queridos", "Apreciados", "Distinguidos", "Honorables", "Estimados", "Respetados"]
marranos = ["compatriotas", "ciudadanos", "amigos", "coterraneos", "coparticarios", "electores"]
poblacion = ["en mi gobierno", "con su apoyo", "siendo elegido", "con su ayuda", "si me siguen", "durante mi mandato"]
compromiso = ["voy a derrotar" ,"venceré" ,"eliminaré" ,"acabaré" ,"lucharé contra","combatiré"]
guerrero = ["la violencia y ", "la delincuencia y", "la corrupcion y", "la inflacion y", "la pobreza y", "el desplazamiento y"]
promesa = ["trabajare por", "garantizare", "protegere", "velare por", "promovere", "defendere"]
beneficio = ["la educacion", "el empleo", "la seguridad", "la paz", "la igualdad", "la salud"]
votos = ["de el pais", "de la ciudad", "de la comunidad", "de el pueblo", "para toda la gente", "de cada colombiano"]

lambetazo_seleccionado = random.choice(lambetazo)
marranos_seleccionado = random.choice(marranos)
poblacion_seleccionado = random.choice(poblacion)
compromiso_seleccionado = random.choice(compromiso)
guerrero_seleccionado = random.choice(guerrero)
promesa_seleccionado = random.choice(promesa)
beneficio_seleccionado = random.choice(beneficio)
votos_seleccionado = random.choice(votos)

print ("El discurso seria algo como: " + lambetazo_seleccionado + " " + marranos_seleccionado + " "  + poblacion_seleccionado + " "  + compromiso_seleccionado + " " + guerrero_seleccionado + " "  + promesa_seleccionado + " "  + beneficio_seleccionado + " "  + votos_seleccionado + ".")
# Out:
# El discurso seria algo como: Respetados compatriotas siendo elegido eliminaré la delincuencia y promovere la paz para toda la gente.
