# %%
from collections import OrderedDict

listamodelos=[]
listaresumida=[]
maxLengthList = 1
while len(listamodelos) < maxLengthList:
    modelos = input()
    listamodelos.append(modelos)
    linea1 = [listamodelos.count("0"),listamodelos.count("1"),listamodelos.count("2"),listamodelos.count("3"), listamodelos.count("4"),listamodelos.count("5"),listamodelos.count("6"),listamodelos.count("7"), listamodelos.count("8"),listamodelos.count("9")]
    linea1.remove(0)
for element in listamodelos:
    if element not in listaresumida:
        listaresumida.append(element)
print(listaresumida)


#4 4 0 4 5 5 5 7
