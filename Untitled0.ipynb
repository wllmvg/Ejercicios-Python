# %%
listamodelos=[]
listamodelos2=[]
maxLengthList = 1


modelos = input().split
listamodelos.append(modelos)
salida1=[listamodelos.count("0"),listamodelos.count("1"),listamodelos.count("2"),listamodelos.count("3"), listamodelos.count("4"),listamodelos.count("5"),listamodelos.count("6"),listamodelos.count("7"), listamodelos.count("8"),listamodelos.count("9")]
salida1.remove(0)
print(salida1)
#listamodelos es  el texto ingresado como tal
# Out:
# 4 4 0 4 5 5 5 7
# [0, 0, 0, 0, 0, 0, 0, 0, 0]
